# %% [markdown]
# # E09 - Recommender System (Python)
# Çoban, Ömer Furkan
#
# This notebook contains the solution for the E09 assignment. The goal is to implement a recommender system and perform similarity analysis on text data.
#
# The project is divided into two main tasks:
# 1.  **Task 1: Similarity Analysis**: We will scrape abstracts from arXiv, preprocess the text, and calculate Jaccard and Cosine similarities to find related papers.
# 2.  **Task 2: Movie Recommendation**: We will parse a movie rating database (SQL), build a User-based Collaborative Filtering model, and predict ratings for specific movies based on a personal profile.

# %% [markdown]
# # Task 1: Similarity Analysis
#
# In this task, we aim to compare scientific papers based on their abstracts. We will fetch the data directly from the web, clean it, and then apply similarity metrics.

# %% [markdown]
# ### 1. Scrape Abstracts from arXiv
# We use the `requests` library to fetch the HTML content of the provided arXiv URLs. Then, we use `BeautifulSoup` to parse the HTML and extract the **Title** (inside `h1` tag with class `title`) and the **Abstract** (inside `blockquote` tag with class `abstract`).

# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import PorterStemmer
from IPython.display import display

urls = [
    "https://arxiv.org/abs/2007.08978",
    "https://arxiv.org/abs/2002.03389",
    "https://arxiv.org/abs/2006.16964",
    "https://arxiv.org/abs/2007.04095",
    "https://arxiv.org/abs/2008.00315",
    "https://arxiv.org/abs/1901.08151",
    "https://arxiv.org/abs/1901.10555",
    "https://arxiv.org/abs/1511.03085",
    "https://arxiv.org/abs/1905.03061",
    "https://arxiv.org/abs/2002.01759"
]

def scrape_arxiv(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract Title
        title_tag = soup.find('h1', class_='title')
        title = title_tag.text.replace('Title:', '').strip() if title_tag else "No Title"
        
        # Extract Abstract
        abstract_tag = soup.find('blockquote', class_='abstract')
        abstract = abstract_tag.text.replace('Abstract:', '').strip() if abstract_tag else "No Abstract"
        
        return {"url": url, "title": title, "abstract": abstract}
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return {"url": url, "title": "Error", "abstract": ""}

print("Scraping abstracts from arXiv...")
papers_data = [scrape_arxiv(url) for url in urls]
df_papers = pd.DataFrame(papers_data)
print("Scraping completed.")
df_papers[['title']]
# Out:
# Scraping abstracts from arXiv...
# Scraping completed.
#                                                title
# 0  A large-scale comparative analysis of Coding S...
# 1  Trust in Data Science: Collaboration, Translat...
# 2                  Data Science: Nature and Pitfalls
# 3              Data science and the art of modelling
# 4          A fresh look at introductory data science
# 5  Cloud BI: Future of Business Intelligence in t...
# 6  The Effects of Using Business Intelligence Sys...
# 7  Big Data and Business Intelligence: Debunking ...
# 8               Generalized formal model of big data
# 9  Quality Assurance Technologies of Big Data App...

# %% [markdown]
# ### 2. Preprocessing
# To ensure accurate similarity calculations, we clean the text data:
# 1.  **Lowercasing**: Convert all text to lower case to treat "Data" and "data" as the same.
# 2.  **Removing Noise**: Remove punctuation, numbers, and special characters.
# 3.  **Stop Word Removal**: Remove common English words (e.g., "the", "is", "at") that do not carry significant meaning.
# 4.  **Stemming**: Reduce words to their root form (e.g., "learning" -> "learn") using the Porter Stemmer.

# %%
# Load Stop Words
try:
    with open('all_stop_words.txt', 'r') as f:
        stop_words = set(f.read().split())
except FileNotFoundError:
    print("Warning: 'all_stop_words.txt' not found. Creating empty set.")
    stop_words = set()

stemmer = PorterStemmer()

def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove special chars and numbers (keep only letters and spaces)
    text = re.sub(r'[^a-z\s]', '', text)
    # Tokenize
    words = text.split()
    # Remove stop words and stem
    words = [stemmer.stem(w) for w in words if w not in stop_words]
    return ' '.join(words)

df_papers['processed_abstract'] = df_papers['abstract'].apply(preprocess_text)
df_papers[['title', 'processed_abstract']].head()
# Out:
#                                                title  \
# 0  A large-scale comparative analysis of Coding S...
# 1  Trust in Data Science: Collaboration, Translat...
# 2                  Data Science: Nature and Pitfalls
# 3              Data science and the art of modelling
# 4          A fresh look at introductory data science
#
#                                   processed_abstract
# 0  background meet grow industri demand data scie...
# 1  trustworthi data scienc system appli realworld...
# 2  data scienc creat excit trend controversi crit...
# 3  datacentr enthusiasm grow strong varieti domai...
# 4  prolifer vast quantiti dataset larg complex na...

# %% [markdown]
# ### 3. Similarity Calculations
# We use two different metrics to calculate similarity between papers:
# *   **Jaccard Similarity**: Measures the overlap between the sets of unique words in two documents.
# *   **Cosine Similarity**: Measures the cosine of the angle between two TF-IDF vectors.

# %%
# Jaccard Similarity
def get_jaccard_similarity(str1, str2):
    a = set(str1.split())
    b = set(str2.split())
    c = a.intersection(b)
    if len(a) + len(b) - len(c) == 0:
        return 0.0
    return float(len(c)) / (len(a) + len(b) - len(c))

# Compute Jaccard Matrix
n = len(df_papers)
jaccard_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        jaccard_matrix[i, j] = get_jaccard_similarity(df_papers.iloc[i]['processed_abstract'], df_papers.iloc[j]['processed_abstract'])

df_jaccard = pd.DataFrame(jaccard_matrix, index=df_papers['title'], columns=df_papers['title'])

# Cosine Similarity using TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df_papers['processed_abstract'])
cosine_matrix = cosine_similarity(tfidf_matrix)

df_cosine = pd.DataFrame(cosine_matrix, index=df_papers['title'], columns=df_papers['title'])

print("Similarity matrices calculated.")

display(df_jaccard)
display(df_cosine)
# Out:
# Similarity matrices calculated.
# title                                               A large-scale comparative analysis of Coding Standard conformance in Open-Source Data Science projects  \
# title
# A large-scale comparative analysis of Coding St...                                           1.000000
# Trust in Data Science: Collaboration, Translati...                                           0.050420
# Data Science: Nature and Pitfalls                                                            0.037975
# Data science and the art of modelling                                                        0.043956
# A fresh look at introductory data science                                                    0.055556
# Cloud BI: Future of Business Intelligence in th...                                           0.037594
# The Effects of Using Business Intelligence Syst...                                           0.046296
# Big Data and Business Intelligence: Debunking t...                                           0.036697
# Generalized formal model of big data                                                         0.018018
# Quality Assurance Technologies of Big Data Appl...                                           0.037879
#
# title                                               Trust in Data Science: Collaboration, Translation, and Accountability in Corporate Data Science Projects  \
# title
# A large-scale comparative analysis of Coding St...                                           0.050420
# Trust in Data Science: Collaboration, Translati...                                           1.000000
# Data Science: Nature and Pitfalls                                                            0.064103
# Data science and the art of modelling                                                        0.054945
# A fresh look at introductory data science                                                    0.072000
# Cloud BI: Future of Business Intelligence in th...                                           0.037313
# The Effects of Using Business Intelligence Syst...                                           0.017857
# Big Data and Business Intelligence: Debunking t...                                           0.045872
# Generalized formal model of big data                                                         0.027027
# Quality Assurance Technologies of Big Data Appl...                                           0.045455
#
# title                                               Data Science: Nature and Pitfalls  \
# title
# A large-scale comparative analysis of Coding St...                           0.037975
# Trust in Data Science: Collaboration, Translati...                           0.064103
# Data Science: Nature and Pitfalls                                            1.000000
# Data science and the art of modelling                                        0.060000
# A fresh look at introductory data science                                    0.058140
# Cloud BI: Future of Business Intelligence in th...                           0.010526
# The Effects of Using Business Intelligence Syst...                           0.028986
# Big Data and Business Intelligence: Debunking t...                           0.075758
# Generalized formal model of big data                                         0.028986
# Quality Assurance Technologies of Big Data Appl...                           0.021505
#
# title                                               Data science and the art of modelling  \
# title
# A large-scale comparative analysis of Coding St...                               0.043956
# Trust in Data Science: Collaboration, Translati...                               0.054945
# Data Science: Nature and Pitfalls                                                0.060000
# Data science and the art of modelling                                            1.000000
# A fresh look at introductory data science                                        0.019608
# Cloud BI: Future of Business Intelligence in th...                               0.028302
# The Effects of Using Business Intelligence Syst...                               0.037037
# Big Data and Business Intelligence: Debunking t...                               0.024390
# Generalized formal model of big data                                             0.024390
# Quality Assurance Technologies of Big Data Appl...                               0.058824
#
# title                                               A fresh look at introductory data science  \
# title
# A large-scale comparative analysis of Coding St...                                   0.055556
# Trust in Data Science: Collaboration, Translati...                                   0.072000
# Data Science: Nature and Pitfalls                                                    0.058140
# Data science and the art of modelling                                                0.019608
# A fresh look at introductory data science                                            1.000000
# Cloud BI: Future of Business Intelligence in th...                                   0.057554
# The Effects of Using Business Intelligence Syst...                                   0.025210
# Big Data and Business Intelligence: Debunking t...                                   0.060870
# Generalized formal model of big data                                                 0.025210
# Quality Assurance Technologies of Big Data Appl...                                   0.089552
#
# title                                               Cloud BI: Future of Business Intelligence in the Cloud  \
# title
# A large-scale comparative analysis of Coding St...                                           0.037594
# Trust in Data Science: Collaboration, Translati...                                           0.037313
# Data Science: Nature and Pitfalls                                                            0.010526
# Data science and the art of modelling                                                        0.028302
# A fresh look at introductory data science                                                    0.057554
# Cloud BI: Future of Business Intelligence in th...                                           1.000000
# The Effects of Using Business Intelligence Syst...                                           0.058333
# Big Data and Business Intelligence: Debunking t...                                           0.024194
# Generalized formal model of big data                                                         0.040984
# Quality Assurance Technologies of Big Data Appl...                                           0.020270
#
# title                                               The Effects of Using Business Intelligence Systems on an Excellence Management and Decision-Making Process by Start-Up Companies: A Case Study  \
# title
# A large-scale comparative analysis of Coding St...                                           0.046296
# Trust in Data Science: Collaboration, Translati...                                           0.017857
# Data Science: Nature and Pitfalls                                                            0.028986
# Data science and the art of modelling                                                        0.037037
# A fresh look at introductory data science                                                    0.025210
# Cloud BI: Future of Business Intelligence in th...                                           0.058333
# The Effects of Using Business Intelligence Syst...                                           1.000000
# Big Data and Business Intelligence: Debunking t...                                           0.051546
# Generalized formal model of big data                                                         0.073684
# Quality Assurance Technologies of Big Data Appl...                                           0.058824
#
# title                                               Big Data and Business Intelligence: Debunking the Myths  \
# title
# A large-scale comparative analysis of Coding St...                                           0.036697
# Trust in Data Science: Collaboration, Translati...                                           0.045872
# Data Science: Nature and Pitfalls                                                            0.075758
# Data science and the art of modelling                                                        0.024390
# A fresh look at introductory data science                                                    0.060870
# Cloud BI: Future of Business Intelligence in th...                                           0.024194
# The Effects of Using Business Intelligence Syst...                                           0.051546
# Big Data and Business Intelligence: Debunking t...                                           1.000000
# Generalized formal model of big data                                                         0.051546
# Quality Assurance Technologies of Big Data Appl...                                           0.041322
#
# title                                               Generalized formal model of big data  \
# title
# A large-scale comparative analysis of Coding St...                              0.018018
# Trust in Data Science: Collaboration, Translati...                              0.027027
# Data Science: Nature and Pitfalls                                               0.028986
# Data science and the art of modelling                                           0.024390
# A fresh look at introductory data science                                       0.025210
# Cloud BI: Future of Business Intelligence in th...                              0.040984
# The Effects of Using Business Intelligence Syst...                              0.073684
# Big Data and Business Intelligence: Debunking t...                              0.051546
# Generalized formal model of big data                                            1.000000
# Quality Assurance Technologies of Big Data Appl...                              0.041322
#
# title                                               Quality Assurance Technologies of Big Data Applications: A Systematic Literature Review
# title
# A large-scale comparative analysis of Coding St...                                           0.037879
# Trust in Data Science: Collaboration, Translati...                                           0.045455
# Data Science: Nature and Pitfalls                                                            0.021505
# Data science and the art of modelling                                                        0.058824
# A fresh look at introductory data science                                                    0.089552
# Cloud BI: Future of Business Intelligence in th...                                           0.020270
# The Effects of Using Business Intelligence Syst...                                           0.058824
# Big Data and Business Intelligence: Debunking t...                                           0.041322
# Generalized formal model of big data                                                         0.041322
# Quality Assurance Technologies of Big Data Appl...                                           1.000000
# title                                               A large-scale comparative analysis of Coding Standard conformance in Open-Source Data Science projects  \
# title
# A large-scale comparative analysis of Coding St...                                           1.000000
# Trust in Data Science: Collaboration, Translati...                                           0.221797
# Data Science: Nature and Pitfalls                                                            0.210570
# Data science and the art of modelling                                                        0.118590
# A fresh look at introductory data science                                                    0.176484
# Cloud BI: Future of Business Intelligence in th...                                           0.022187
# The Effects of Using Business Intelligence Syst...                                           0.051753
# Big Data and Business Intelligence: Debunking t...                                           0.104708
# Generalized formal model of big data                                                         0.054145
# Quality Assurance Technologies of Big Data Appl...                                           0.065709
#
# title                                               Trust in Data Science: Collaboration, Translation, and Accountability in Corporate Data Science Projects  \
# title
# A large-scale comparative analysis of Coding St...                                           0.221797
# Trust in Data Science: Collaboration, Translati...                                           1.000000
# Data Science: Nature and Pitfalls                                                            0.290747
# Data science and the art of modelling                                                        0.162726
# A fresh look at introductory data science                                                    0.220096
# Cloud BI: Future of Business Intelligence in th...                                           0.032697
# The Effects of Using Business Intelligence Syst...                                           0.020061
# Big Data and Business Intelligence: Debunking t...                                           0.161983
# Generalized formal model of big data                                                         0.083947
# Quality Assurance Technologies of Big Data Appl...                                           0.070441
#
# title                                               Data Science: Nature and Pitfalls  \
# title
# A large-scale comparative analysis of Coding St...                           0.210570
# Trust in Data Science: Collaboration, Translati...                           0.290747
# Data Science: Nature and Pitfalls                                            1.000000
# Data science and the art of modelling                                        0.160156
# A fresh look at introductory data science                                    0.236506
# Cloud BI: Future of Business Intelligence in th...                           0.013275
# The Effects of Using Business Intelligence Syst...                           0.026361
# Big Data and Business Intelligence: Debunking t...                           0.194679
# Generalized formal model of big data                                         0.098362
# Quality Assurance Technologies of Big Data Appl...                           0.073674
#
# title                                               Data science and the art of modelling  \
# title
# A large-scale comparative analysis of Coding St...                               0.118590
# Trust in Data Science: Collaboration, Translati...                               0.162726
# Data Science: Nature and Pitfalls                                                0.160156
# Data science and the art of modelling                                            1.000000
# A fresh look at introductory data science                                        0.084061
# Cloud BI: Future of Business Intelligence in th...                               0.022315
# The Effects of Using Business Intelligence Syst...                               0.023710
# Big Data and Business Intelligence: Debunking t...                               0.087156
# Generalized formal model of big data                                             0.075778
# Quality Assurance Technologies of Big Data Appl...                               0.077101
#
# title                                               A fresh look at introductory data science  \
# title
# A large-scale comparative analysis of Coding St...                                   0.176484
# Trust in Data Science: Collaboration, Translati...                                   0.220096
# Data Science: Nature and Pitfalls                                                    0.236506
# Data science and the art of modelling                                                0.084061
# A fresh look at introductory data science                                            1.000000
# Cloud BI: Future of Business Intelligence in th...                                   0.077441
# The Effects of Using Business Intelligence Syst...                                   0.024227
# Big Data and Business Intelligence: Debunking t...                                   0.145812
# Generalized formal model of big data                                                 0.058686
# Quality Assurance Technologies of Big Data Appl...                                   0.081652
#
# title                                               Cloud BI: Future of Business Intelligence in the Cloud  \
# title
# A large-scale comparative analysis of Coding St...                                           0.022187
# Trust in Data Science: Collaboration, Translati...                                           0.032697
# Data Science: Nature and Pitfalls                                                            0.013275
# Data science and the art of modelling                                                        0.022315
# A fresh look at introductory data science                                                    0.077441
# Cloud BI: Future of Business Intelligence in th...                                           1.000000
# The Effects of Using Business Intelligence Syst...                                           0.188607
# Big Data and Business Intelligence: Debunking t...                                           0.036128
# Generalized formal model of big data                                                         0.030853
# Quality Assurance Technologies of Big Data Appl...                                           0.057566
#
# title                                               The Effects of Using Business Intelligence Systems on an Excellence Management and Decision-Making Process by Start-Up Companies: A Case Study  \
# title
# A large-scale comparative analysis of Coding St...                                           0.051753
# Trust in Data Science: Collaboration, Translati...                                           0.020061
# Data Science: Nature and Pitfalls                                                            0.026361
# Data science and the art of modelling                                                        0.023710
# A fresh look at introductory data science                                                    0.024227
# Cloud BI: Future of Business Intelligence in th...                                           0.188607
# The Effects of Using Business Intelligence Syst...                                           1.000000
# Big Data and Business Intelligence: Debunking t...                                           0.064046
# Generalized formal model of big data                                                         0.072155
# Quality Assurance Technologies of Big Data Appl...                                           0.056584
#
# title                                               Big Data and Business Intelligence: Debunking the Myths  \
# title
# A large-scale comparative analysis of Coding St...                                           0.104708
# Trust in Data Science: Collaboration, Translati...                                           0.161983
# Data Science: Nature and Pitfalls                                                            0.194679
# Data science and the art of modelling                                                        0.087156
# A fresh look at introductory data science                                                    0.145812
# Cloud BI: Future of Business Intelligence in th...                                           0.036128
# The Effects of Using Business Intelligence Syst...                                           0.064046
# Big Data and Business Intelligence: Debunking t...                                           1.000000
# Generalized formal model of big data                                                         0.362810
# Quality Assurance Technologies of Big Data Appl...                                           0.269354
#
# title                                               Generalized formal model of big data  \
# title
# A large-scale comparative analysis of Coding St...                              0.054145
# Trust in Data Science: Collaboration, Translati...                              0.083947
# Data Science: Nature and Pitfalls                                               0.098362
# Data science and the art of modelling                                           0.075778
# A fresh look at introductory data science                                       0.058686
# Cloud BI: Future of Business Intelligence in th...                              0.030853
# The Effects of Using Business Intelligence Syst...                              0.072155
# Big Data and Business Intelligence: Debunking t...                              0.362810
# Generalized formal model of big data                                            1.000000
# Quality Assurance Technologies of Big Data Appl...                              0.341554
#
# title                                               Quality Assurance Technologies of Big Data Applications: A Systematic Literature Review
# title
# A large-scale comparative analysis of Coding St...                                           0.065709
# Trust in Data Science: Collaboration, Translati...                                           0.070441
# Data Science: Nature and Pitfalls                                                            0.073674
# Data science and the art of modelling                                                        0.077101
# A fresh look at introductory data science                                                    0.081652
# Cloud BI: Future of Business Intelligence in th...                                           0.057566
# The Effects of Using Business Intelligence Syst...                                           0.056584
# Big Data and Business Intelligence: Debunking t...                                           0.269354
# Generalized formal model of big data                                                         0.341554
# Quality Assurance Technologies of Big Data Appl...                                           1.000000

# %% [markdown]
# ### 4. Results: Most Similar Papers
# We present the results in a readable table format, identifying the most similar paper for each entry.

# %%
def get_most_similar_df(sim_df):
    # Mask diagonal to avoid self-matching
    np.fill_diagonal(sim_df.values, -1)
    
    results = []
    for title in sim_df.index:
        most_sim_title = sim_df.loc[title].idxmax()
        score = sim_df.loc[title].max()
        results.append({
            "Paper": title,
            "Most Similar Paper": most_sim_title,
            "Score": score
        })
    return pd.DataFrame(results).sort_values("Score", ascending=False)

print("--- Jaccard Similarity Results ---")
display(get_most_similar_df(df_jaccard))

print("\n--- Cosine Similarity Results ---")
display(get_most_similar_df(df_cosine))
# Out:
# --- Jaccard Similarity Results ---
#                                                Paper  \
# 4          A fresh look at introductory data science
# 9  Quality Assurance Technologies of Big Data App...
# 2                  Data Science: Nature and Pitfalls
# 7  Big Data and Business Intelligence: Debunking ...
# 6  The Effects of Using Business Intelligence Sys...
# 8               Generalized formal model of big data
# 1  Trust in Data Science: Collaboration, Translat...
# 3              Data science and the art of modelling
# 5  Cloud BI: Future of Business Intelligence in t...
# 0  A large-scale comparative analysis of Coding S...
#
#                                   Most Similar Paper     Score
# 4  Quality Assurance Technologies of Big Data App...  0.089552
# 9          A fresh look at introductory data science  0.089552
# 2  Big Data and Business Intelligence: Debunking ...  0.075758
# 7                  Data Science: Nature and Pitfalls  0.075758
# 6               Generalized formal model of big data  0.073684
# 8  The Effects of Using Business Intelligence Sys...  0.073684
# 1          A fresh look at introductory data science  0.072000
# 3                  Data Science: Nature and Pitfalls  0.060000
# 5  The Effects of Using Business Intelligence Sys...  0.058333
# 0          A fresh look at introductory data science  0.055556
# --- Cosine Similarity Results ---
#                                                Paper  \
# 7  Big Data and Business Intelligence: Debunking ...
# 8               Generalized formal model of big data
# 9  Quality Assurance Technologies of Big Data App...
# 1  Trust in Data Science: Collaboration, Translat...
# 2                  Data Science: Nature and Pitfalls
# 4          A fresh look at introductory data science
# 0  A large-scale comparative analysis of Coding S...
# 5  Cloud BI: Future of Business Intelligence in t...
# 6  The Effects of Using Business Intelligence Sys...
# 3              Data science and the art of modelling
#
#                                   Most Similar Paper     Score
# 7               Generalized formal model of big data  0.362810
# 8  Big Data and Business Intelligence: Debunking ...  0.362810
# 9               Generalized formal model of big data  0.341554
# 1                  Data Science: Nature and Pitfalls  0.290747
# 2  Trust in Data Science: Collaboration, Translat...  0.290747
# 4                  Data Science: Nature and Pitfalls  0.236506
# 0  Trust in Data Science: Collaboration, Translat...  0.221797
# 5  The Effects of Using Business Intelligence Sys...  0.188607
# 6  Cloud BI: Future of Business Intelligence in t...  0.188607
# 3  Trust in Data Science: Collaboration, Translat...  0.162726

# %% [markdown]
# # Task 2: Movie Recommendation
#
# In this task, we implement a recommender system using User-based Collaborative Filtering. We start with a SQL database dump, parse it into a usable format, and then build the recommendation engine to predict missing ratings.

# %% [markdown]
# ### 1. Parse SQL & Generate CSVs
# The data is provided in a PostgreSQL dump file (`ratingdb_postgresql.sql`). We use Regular Expressions (`re`) to parse the `INSERT` statements and extract data for:
# *   **Movies**: ID, Title, Release Year, Director.
# *   **Reviewers**: ID, Name.
# *   **Ratings**: Reviewer ID, Movie ID, Stars, Date.
#
# We then save these structured datasets as CSV files for easier loading.

# %%
# Read SQL file
sql_file = 'ratingdb_postgresql.sql'
try:
    with open(sql_file, 'r') as f:
        sql_content = f.read()
    
    # Extract Movies
    movies = []
    movie_matches = re.findall(r"INSERT INTO movie \(m_id,title,release_year,director\) VALUES \((\d+),'([^']*)',(\d+),([^)]*)\);", sql_content)
    for match in movie_matches:
        m_id, title, year, director = match
        director = director.strip("'") if director != 'NULL' else None
        movies.append({'m_id': int(m_id), 'title': title, 'year': int(year), 'director': director})
    
    df_movies_extracted = pd.DataFrame(movies)
    df_movies_extracted.to_csv('movies.csv', index=False)
    print("Created movies.csv")
    
    # Extract Reviewers
    reviewers = []
    reviewer_matches = re.findall(r"INSERT INTO reviewer \(r_id,reviewer_name\) VALUES \((\d+),'([^']*)'\);", sql_content)
    for match in reviewer_matches:
        r_id, name = match
        reviewers.append({'r_id': int(r_id), 'reviewer_name': name})
    
    df_reviewers_extracted = pd.DataFrame(reviewers)
    df_reviewers_extracted.to_csv('reviewers.csv', index=False)
    print("Created reviewers.csv")
    
    # Extract Ratings
    ratings = []
    rating_matches = re.findall(r"INSERT INTO rating \(r_id,m_id,stars,rating_date\) VALUES \((\d+),(\d+),(\d+),([^)]*)\);", sql_content)
    for match in rating_matches:
        r_id, m_id, stars, date = match
        date = date.strip("'") if date != 'NULL' else None
        ratings.append({'r_id': int(r_id), 'm_id': int(m_id), 'stars': int(stars), 'date': date})
    
    df_ratings_extracted = pd.DataFrame(ratings)
    df_ratings_extracted.to_csv('ratings.csv', index=False)
    print("Created ratings.csv")
    
except FileNotFoundError:
    print(f"Error: {sql_file} not found. Utilizing existing CSVs if available.")
# Out:
# Created movies.csv
# Created reviewers.csv
# Created ratings.csv

# %% [markdown]
# ### 2. Prepare Rating Matrix (Pivot Table)
# We merge the extracted CSVs into a single DataFrame and then create a Pivot Table.
# *   **Rows**: Reviewers
# *   **Columns**: Movies
# *   **Values**: Ratings (Stars)
#
# This matrix is the foundation for Collaborative Filtering.

# %%
df_movies = pd.read_csv('movies.csv')
df_ratings = pd.read_csv('ratings.csv')
df_reviewers = pd.read_csv('reviewers.csv')

# Merge
df = pd.merge(df_ratings, df_movies, on='m_id')
df = pd.merge(df, df_reviewers, on='r_id')

# Pivot Table (Users x Movies)
df_pivot = df.pivot_table(index='reviewer_name', columns='title', values='stars', aggfunc='mean')

# Ensure all movies are columns
all_movie_titles = df_movies['title'].unique()
df_pivot = df_pivot.reindex(columns=all_movie_titles)

print("Rating Matrix Shape:", df_pivot.shape)
df_pivot
# Out:
# Rating Matrix Shape: (8, 8)
# title             Gone with the Wind  Star Wars  The Sound of Music  E.T.  \
# reviewer_name
# Ashley White                     NaN        NaN                 NaN   3.0
# Brittany Harris                  NaN        NaN                 2.0   NaN
# Chris Jackson                    NaN        NaN                 3.0   2.0
# Daniel Lewis                     NaN        NaN                 NaN   NaN
# Elizabeth Thomas                 NaN        NaN                 NaN   NaN
# James Cameron                    NaN        NaN                 NaN   NaN
# Mike Anderson                    3.0        NaN                 NaN   NaN
# Sarah Martinez                   3.0        NaN                 NaN   NaN
#
# title             Titanic  Snow White  Avatar  Raiders of the Lost Ark
# reviewer_name
# Ashley White          NaN         NaN     NaN                      NaN
# Brittany Harris       NaN         NaN     NaN                      3.0
# Chris Jackson         NaN         NaN     NaN                      4.0
# Daniel Lewis          NaN         4.0     NaN                      NaN
# Elizabeth Thomas      NaN         5.0     3.0                      NaN
# James Cameron         NaN         NaN     5.0                      NaN
# Mike Anderson         NaN         NaN     NaN                      NaN
# Sarah Martinez        NaN         NaN     NaN                      NaN

# %% [markdown]
# ### 3. Collaborative Filtering (User-Based)
# We employ **User-based Collaborative Filtering**. The core idea is that users who agreed in the past (gave similar ratings) will agree in the future.
#
# 1.  **Centering**: Different users have different baseline ratings (some are generous, some critical). We normalize this by subtracting each user's mean rating from their scores.
# 2.  **Cosine Similarity**: We calculate the similarity between all pairs of users using the centered ratings.

# %%
# Center the ratings (subtract user mean)
df_centered = df_pivot.apply(lambda x: x - x.mean(), axis=1).fillna(0)

# User Similarity
user_sim = cosine_similarity(df_centered)
user_sim_df = pd.DataFrame(user_sim, index=df_pivot.index, columns=df_pivot.index)

# Item Similarity (Transposed)
item_sim = cosine_similarity(df_centered.T)
item_sim_df = pd.DataFrame(item_sim, index=df_pivot.columns, columns=df_pivot.columns)

print("Similarities calculated.")
# Out:
# Similarities calculated.

# %% [markdown]
# ## Questions
#
# **1. Which algorithm did you select and why?**
# I selected **User-based Collaborative Filtering with Centered Cosine Similarity**. This method is effective because it:
# *   **Handles Bias**: Centering removes individual rating biases (optimism/pessimism).
# *   **Leverages Community**: It uses the collective wisdom of similar users to predict unknown preferences.

# %% [markdown]
# ### 4. Identify Most Similar Movies & Users
# Using the calculated similarity matrices, we can now answer:
# *   Which two movies are most similar based on user ratings?
# *   Which two users have the most similar taste?

# %%
def get_most_similar_pair(sim_df):
    sim_stack = sim_df.stack()
    # Filter out identity (score close to 1.0)
    sim_stack = sim_stack[sim_stack < 0.9999]
    return sim_stack.idxmax(), sim_stack.max()

# Similar Movies
movie_pair, movie_score = get_most_similar_pair(item_sim_df)
print(f"Most similar movies: '{movie_pair[0]}' and '{movie_pair[1]}' (Score: {movie_score:.4f})")

# Similar Users
user_pair, user_score = get_most_similar_pair(user_sim_df)
print(f"Most similar users: '{user_pair[0]}' and '{user_pair[1]}' (Score: {user_score:.4f})")
# Out:
# Most similar movies: 'Gone with the Wind' and 'Gone with the Wind' (Score: 0.0000)
# Most similar users: 'Brittany Harris' and 'Chris Jackson' (Score: 0.5000)

# %% [markdown]
# ### 5. Personal Recommendations
# Finally, we put the recommender to the test.
# 1.  **Create Profile**: Add a "My Profile" user with specific ratings (e.g., liking *Star Wars*).
# 2.  **Re-calculate Similarities**: Update the user similarity matrix to include this new profile.
# 3.  **Predict Ratings**: Estimate ratings for movies the profile hasn't seen yet (e.g., *E.T.*, *Titanic*) by taking a weighted average of ratings from the most similar users.

# %%
# Create My Profile
my_ratings = pd.Series(name='My Profile', dtype=float)
my_ratings['Star Wars'] = 5.0
my_ratings['Raiders of the Lost Ark'] = 5.0
my_ratings['Avatar'] = 4.0

# Add to Pivot
df_pivot_with_me = pd.concat([df_pivot, my_ratings.to_frame().T])

# Re-calculate similarities
df_centered_with_me = df_pivot_with_me.apply(lambda x: x - x.mean(), axis=1).fillna(0)
user_sim_with_me = cosine_similarity(df_centered_with_me)
user_sim_with_me_df = pd.DataFrame(user_sim_with_me, index=df_pivot_with_me.index, columns=df_pivot_with_me.index)

def predict_rating(user, item, pivot_df, sim_df):
    # Get similar users
    user_similarities = sim_df[user].sort_values(ascending=False).drop(user)
    # Get ratings for the item
    item_ratings = pivot_df[item].drop(user).dropna()
    
    # Intersection
    relevant_users = item_ratings.index.intersection(user_similarities.index)
    
    if len(relevant_users) == 0:
        return pivot_df.loc[user].mean()
        
    weights = user_similarities[relevant_users]
    if weights.sum() == 0:
        return pivot_df.loc[user].mean()
        
    ratings = item_ratings[relevant_users]
    
    prediction = np.dot(weights, ratings) / weights.sum()
    return prediction

# Predict for unrated movies
target_movies = ['E.T.', 'Titanic']
print("--- Predictions for My Profile ---")
for movie in target_movies:
    pred = predict_rating('My Profile', movie, df_pivot_with_me, user_sim_with_me_df)
    print(f"Predicted rating for '{movie}': {pred:.2f}")
# Out:
# --- Predictions for My Profile ---
# Predicted rating for 'E.T.': 2.00
# Predicted rating for 'Titanic': 4.67
